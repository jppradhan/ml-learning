# %%
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv('bikes.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet(growth='linear', daily_seasonality=True, weekly_seasonality=True, yearly_seasonality=True)
m.fit(df)

# %%
future = m.make_future_dataframe(periods=365*5)
future.tail()
# Out:
#              ds
# 4725 2021-01-14
# 4726 2021-01-15
# 4727 2021-01-16
# 4728 2021-01-17
# 4729 2021-01-18

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat']].tail()
# Out:
#              ds      yhat
# 4725 2021-01-14  6.562040
# 4726 2021-01-15  6.586517
# 4727 2021-01-16  6.365381
# 4728 2021-01-17  6.745413
# 4729 2021-01-18  7.068363

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
print(forecast[['yhat']])
# Out:
#           yhat
# 0     8.842773
# 1     8.591294
# 2     8.387111
# 3     8.364994
# 4     8.352969
# ...        ...
# 4725  6.562040
# 4726  6.586517
# 4727  6.365381
# 4728  6.745413
# 4729  7.068363
#
# [4730 rows x 1 columns]
